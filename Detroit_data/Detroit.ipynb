# %%
import pandas as pd
import numpy as np
df_detroit = pd.read_csv('https://query.data.world/s/afon5msowjjtjobbvtxin6y5cpkcoi')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_detroit.head()
# Out:
#    ROWNUM   CASEID  CRIMEID          CRNO                     ADDRESS  \
# 0       1  1099487  1321797  0910020373.1               18000 WEXFORD
# 1       2  1117507  1344185  0911060289.1                  00 UNKNOWN
# 2       3   985415  1181882  0902190512.1               02000 CALVERT
# 3       4   986019  1182632  0902200294.1  00 W GRAND BLVD AND W FORT
# 4       5   996883  1195867  0903170149.1                12500 CONNER
#
#         CATEGORY                                 OFFENSEDESCRIPTION  \
# 0  MISCELLANEOUS               MISCELLANEOUS - GENERAL NON-CRIMINAL
# 1  MISCELLANEOUS               MISCELLANEOUS - GENERAL NON-CRIMINAL
# 2  MISCELLANEOUS                  MISCELLANEOUS - ABANDONED VEHICLE
# 3  MISCELLANEOUS               MISCELLANEOUS - GENERAL NON-CRIMINAL
# 4        LARCENY  LARCENY - FROM BUILDING (INCLUDES LIBRARY, OFF...
#
#    STATEOFFENSEFILECLASS INCIDENTDATE  HOUR     SCA  PRECINCT  \
# 0                99009.0   01/01/2009     0  1107.0      11.0
# ...

# %%
#pull out columns we are interested in
reduced_df_detroit = df_detroit.loc[:, ["CATEGORY", "OFFENSEDESCRIPTION", "INCIDENTDATE", "HOUR", "LON", "LAT"]]
reduced_df_detroit
# Out:
#                        CATEGORY  \
# 0                 MISCELLANEOUS
# 1                 MISCELLANEOUS
# 2                 MISCELLANEOUS
# 3                 MISCELLANEOUS
# 4                       LARCENY
# 5                       LARCENY
# 6                       LARCENY
# 7                         FRAUD
# 8                       ASSAULT
# 9            DAMAGE TO PROPERTY
# 10                      LARCENY
# 11                MISCELLANEOUS
# 12           MURDER/INFORMATION
# 13                      LARCENY
# 14           MURDER/INFORMATION
# 15                        FRAUD
# 16           MURDER/INFORMATION
# 17                MISCELLANEOUS
# 18                        FRAUD
# 19                      LARCENY
# 20                        FRAUD
# 21                        FRAUD
# 22                      LARCENY
# 23                        FRAUD
# 24           MURDER/INFORMATION
# 25           AGGRAVATED ASSAULT
# 26           DAMAGE TO PROPERTY
# 27           MURDER/INFORMATION
# ...

# %%
#drop rows with null values
reduced_df_detroit.dropna()
# Out:
#                        CATEGORY  \
# 0                 MISCELLANEOUS
# 1                 MISCELLANEOUS
# 2                 MISCELLANEOUS
# 3                 MISCELLANEOUS
# 4                       LARCENY
# 5                       LARCENY
# 6                       LARCENY
# 7                         FRAUD
# 8                       ASSAULT
# 9            DAMAGE TO PROPERTY
# 10                      LARCENY
# 11                MISCELLANEOUS
# 12           MURDER/INFORMATION
# 13                      LARCENY
# 14           MURDER/INFORMATION
# 15                        FRAUD
# 16           MURDER/INFORMATION
# 17                MISCELLANEOUS
# 18                        FRAUD
# 19                      LARCENY
# 20                        FRAUD
# 21                        FRAUD
# 22                      LARCENY
# 23                        FRAUD
# 24           MURDER/INFORMATION
# 25           AGGRAVATED ASSAULT
# 26           DAMAGE TO PROPERTY
# 27           MURDER/INFORMATION
# ...

# %%
#check the data types for columns in the cleaned-up data
reduced_df_detroit.dtypes
# Out:
# CATEGORY               object
# OFFENSEDESCRIPTION     object
# INCIDENTDATE           object
# HOUR                    int64
# LON                   float64
# LAT                   float64
# dtype: object

# %%
#pd.to_datetime(df['date'])
#trying to parce the data fram data to only include crime from 2014 and 2015
#detroit_14_15_df=reduced_df_detroit.loc[reduced_df_detroit["INCIDENTDATE"].str.contains("2015", "2014"), :]

#reduced_df_detroit.loc[reduced_df_detroit["INCIDENTDATE"] > 01/01/2014]

#dates_reduced_df_detroit=reduced_df_detroit.dt.strftime('%Y-%m-%d')

# %%
#convert the INCIDENTDATE column from an object to data time  because cannot sort objects
int_data_reduced_df_detroit = pd.to_datetime(reduced_df_detroit['INCIDENTDATE'])
int_data_reduced_df_detroit.head()
# Out:
# 0   2009-01-01
# 1   2009-01-01
# 2   2009-01-01
# 3   2009-01-01
# 4   2009-01-01
# Name: INCIDENTDATE, dtype: datetime64[ns]

# %%
#print data type for column INCIDENTDATE
int_data_reduced_df_detroit.dtypes
# Out:
# dtype('<M8[ns]')

# %%
#merge int_data_reduced_df_detroit and reduced_df_detroit
##int_data_reduced_df_detroit_pd=int_data_reduced_df_detroit
##reduced_df_detroit_pd=reduced_df_detroit
##merge_table = pd.merge(int_data_reduced_df_detroit_pd, reduced_df_detroit_pd, how="outer")
##merge_table
##pd.concat(int_data_reduced_df_detroit, reduced_df_detroit, axis=2, join='outer', join_axes=None, ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, copy=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-4a16c565e449> in <module>()
#       2 int_data_reduced_df_detroit_pd=int_data_reduced_df_detroit
#       3 reduced_df_detroit_pd=reduced_df_detroit
# ----> 4 merge_table = pd.merge(int_data_reduced_df_detroit_pd, reduced_df_detroit_pd, how="outer")
#       5 merge_table
#       6 ##pd.concat(int_data_reduced_df_detroit, reduced_df_detroit, axis=2, join='outer', join_axes=None, ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, copy=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ...

# %%
#splitting the year off of the INCIDENTDATE column because cannot perform loc function for year with the whole date
reduced_df_detroit[['INCIDENTDATE','year']] = reduced_df_detroit['INCIDENTDATE'].str.split('/',expand=True)
reduced_df_detroit
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-2b2c5697a0ba> in <module>()
#       1 #splitting the year off of the INCIDENTDATE column
# ----> 2 reduced_df_detroit[['INCIDENTDATE','year']] = reduced_df_detroit['INCIDENTDATE'].str.split('/',expand=True)
#       3 reduced_df_detroit
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3114             self._setitem_frame(key, value)
#    3115         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3116             self._setitem_array(key, value)
#    3117         else:
#    3118             # set column
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3136             if isinstance(value, DataFrame):
#    3137                 if len(value.columns) != len(key):
# ...

# %%
#convert the date to UTC time 
#reduced_df_detroit['INCIDENTDATE'] = pd.to_datetime(df['INCIDENTDATE'],unit='s')

# %%
#insolate data from years 01/01/2014 through 12/31/2015
#reduced_df_detroit.loc[reduced_df_detroit.INCIDENTDATE <= 01/01/2014, 'equal_or_lower_than_4?'] = 'True' 
#reduced_df_detroit.loc[reduced_df_detroit.INCIDENTDATE  > 01/01/2014, 'equal_or_lower_than_4?'] = 'False' 

#reduced_df_detroit.head()
